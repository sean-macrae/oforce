# %%
import datetime 
import numpy as np
import pandas as pd
from pandas.io import gbq
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize

# %%
# Query Theia
projectid = 'aerial-jigsaw-823'
query = """SELECT * 
FROM
maxtestdataset_STG.maxtesttable_seg_com_STG"""
df = pd.read_gbq(query, project_id = projectid, reauth=False)
# Out:
# Job not yet complete...

# %%
df.describe()
# Out:
#        version   type  userId    path referrer search  \
# count      498    498       0     107      107    107
# unique       1      3       0      12       14     11
# top          2  track     NaN  /login
# freq       498    349     NaN      33       33     80
#
#                           title                                           url  \
# count                       107                                           107
# unique                        1                                            21
# top     Oration Consumer Portal  https://stg-consumerapp-01.oration.com/login
# freq                        107                                            33
#
#                        timestamp                       event      ...       \
# count                        498                         349      ...
# unique                       496                          44      ...
# top     2015-02-06T02:36:55.853Z  PrescriptionManagementCtrl      ...
# freq                           2                          50      ...
#
#        familyRebate familySize memberActualRebate memberActualSavings  \
# count             5          5                  5                   5
# unique            2          2                  2                   3
# top              20          4                  0                   0
# freq              4          4                  4                   3
#
#        memberNumActualOneTimeFreeFills memberNumActualPerpetualFreeFills  \
# count                                5                                 5
# unique                               1                                 1
# top                                  0                                 0
# freq                                 5                                 5
#
#        memberNumPotentialOneTimeFreeFills  \
# count                                   5
# unique                                  1
# top                                     0
# freq                                    5
#
#        memberNumPotentialPerpetualFreeFills memberRebate memberSavings
# count                                     5            5             5
# unique                                    1            2             3
# top                                       0           10             0
# freq                                      5            3             2
#
# [4 rows x 58 columns]

# %%
theia_path = r'/Users/smacrae/Documents/audit.csv'

df.to_csv(theia_path)

# %%
df['userId'].unique()
# Out:
# array([None], dtype=object)
