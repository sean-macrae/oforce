# %%
import twitter

# XXX: Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = 'OtjXtqXk7Lukum1CDT3gA'
CONSUMER_SECRET = 'NIBTGA35dPDFdk1UhVREQTMd8Yy4093sXrPub5JKDU'
OAUTH_TOKEN = '23175252-BglPZ4LoWNn8TL2wRIR3ipC3TzrGIdRg3XeopbmKK'
OAUTH_TOKEN_SECRET = 'HfZA5dBvR9K5Y5eR4PLJCc6LvGUgeJ07FqqMtBc'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print twitter_api
# Out:
# <twitter.api.Twitter object at 0x1049a8dd0>

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print world_trends
print
print us_trends
# Out:
# [{u'created_at': u'2014-02-01T03:02:07Z', u'trends': [{u'url': u'http://twitter.com/search?q=%2320picturesofharryfromyourcameraroll', u'query': u'%2320picturesofharryfromyourcameraroll', u'name': u'#20picturesofharryfromyourcameraroll', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%2320ReasonsWhyWeLoveHarry', u'query': u'%2320ReasonsWhyWeLoveHarry', u'name': u'#20ReasonsWhyWeLoveHarry', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23BrentTo400k', u'query': u'%23BrentTo400k', u'name': u'#BrentTo400k', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23HappyBirthdayHarry', u'query': u'%23HappyBirthdayHarry', u'name': u'#HappyBirthdayHarry', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23SumaYEnamoraQue', u'query': u'%23SumaYEnamoraQue', u'name': u'#SumaYEnamoraQue', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%22Jeff+Van+Gundy%22', u'query': u'%22Jeff+Van+Gundy%22', u'name': u'Jeff Van Gundy', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%22Bill+Clinton%22', u'query': u'%22Bill+Clinton%22', u'name': u'Bill Clinton', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%22Mike+Conley%22', u'query': u'%22Mike+Conley%22', u'name': u'Mike Conley', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%22Serge+Ibaka%22', u'query': u'%22Serge+Ibaka%22', u'name': u'Serge Ibaka', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=Sonics', u'query': u'Sonics', u'name': u'Sonics', u'promoted_content': None, u'events': None}], u'as_of': u'2014-02-01T03:03:04Z', u'locations': [{u'woeid': 1, u'name': u'Worldwide'}]}]
#
# [{u'created_at': u'2014-02-01T02:52:49Z', u'trends': [{u'url': u'http://twitter.com/search?q=%2320picturesofharryfromyourcameraroll', u'query': u'%2320picturesofharryfromyourcameraroll', u'name': u'#20picturesofharryfromyourcameraroll', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%2320ReasonsWhyWeLoveHarry', u'query': u'%2320ReasonsWhyWeLoveHarry', u'name': u'#20ReasonsWhyWeLoveHarry', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23Cycloramic', u'query': u'%23Cycloramic', u'name': u'#Cycloramic', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23BrentTo400k', u'query': u'%23BrentTo400k', u'name': u'#BrentTo400k', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23GU2014', u'query': u'%23GU2014', u'name': u'#GU2014', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%22Dirty+Dancing%22', u'query': u'%22Dirty+Dancing%22', u'name': u'Dirty Dancing', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%22Nate+Robinson%22', u'query': u'%22Nate+Robinson%22', u'name': u'Nate Robinson', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%22The+Nets%22', u'query': u'%22The+Nets%22', u'name': u'The Nets', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%22Jason+Kidd%22', u'query': u'%22Jason+Kidd%22', u'name': u'Jason Kidd', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%22My+Friday%22', u'query': u'%22My+Friday%22', u'name': u'My Friday', u'promoted_content': None, u'events': None}], u'as_of': u'2014-02-01T03:03:04Z', u'locations': [{u'woeid': 23424977, u'name': u'United States'}]}]

# %%
import json

print json.dumps(world_trends, indent=1)
print
print json.dumps(us_trends, indent=1)
# Out:
# [
#  {
#   "created_at": "2014-02-01T03:02:07Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%2320picturesofharryfromyourcameraroll",
#     "query": "%2320picturesofharryfromyourcameraroll",
#     "name": "#20picturesofharryfromyourcameraroll",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%2320ReasonsWhyWeLoveHarry",
#     "query": "%2320ReasonsWhyWeLoveHarry",
#     "name": "#20ReasonsWhyWeLoveHarry",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BrentTo400k",
#     "query": "%23BrentTo400k",
#     "name": "#BrentTo400k",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HappyBirthdayHarry",
#     "query": "%23HappyBirthdayHarry",
#     "name": "#HappyBirthdayHarry",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SumaYEnamoraQue",
#     "query": "%23SumaYEnamoraQue",
#     "name": "#SumaYEnamoraQue",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Jeff+Van+Gundy%22",
#     "query": "%22Jeff+Van+Gundy%22",
#     "name": "Jeff Van Gundy",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Bill+Clinton%22",
#     "query": "%22Bill+Clinton%22",
#     "name": "Bill Clinton",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Mike+Conley%22",
#     "query": "%22Mike+Conley%22",
#     "name": "Mike Conley",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Serge+Ibaka%22",
#     "query": "%22Serge+Ibaka%22",
#     "name": "Serge Ibaka",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Sonics",
#     "query": "Sonics",
#     "name": "Sonics",
#     "promoted_content": null,
#     "events": null
#    }
#   ],
#   "as_of": "2014-02-01T03:03:04Z",
#   "locations": [
#    {
#     "woeid": 1,
#     "name": "Worldwide"
#    }
#   ]
#  }
# ]
#
# [
#  {
#   "created_at": "2014-02-01T02:52:49Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%2320picturesofharryfromyourcameraroll",
#     "query": "%2320picturesofharryfromyourcameraroll",
#     "name": "#20picturesofharryfromyourcameraroll",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%2320ReasonsWhyWeLoveHarry",
#     "query": "%2320ReasonsWhyWeLoveHarry",
#     "name": "#20ReasonsWhyWeLoveHarry",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Cycloramic",
#     "query": "%23Cycloramic",
#     "name": "#Cycloramic",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BrentTo400k",
#     "query": "%23BrentTo400k",
#     "name": "#BrentTo400k",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23GU2014",
#     "query": "%23GU2014",
#     "name": "#GU2014",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Dirty+Dancing%22",
#     "query": "%22Dirty+Dancing%22",
#     "name": "Dirty Dancing",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Nate+Robinson%22",
#     "query": "%22Nate+Robinson%22",
#     "name": "Nate Robinson",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22The+Nets%22",
#     "query": "%22The+Nets%22",
#     "name": "The Nets",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Jason+Kidd%22",
#     "query": "%22Jason+Kidd%22",
#     "name": "Jason Kidd",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22My+Friday%22",
#     "query": "%22My+Friday%22",
#     "name": "My Friday",
#     "promoted_content": null,
#     "events": null
#    }
#   ],
#   "as_of": "2014-02-01T03:03:04Z",
#   "locations": [
#    {
#     "woeid": 23424977,
#     "name": "United States"
#    }
#   ]
#  }
# ]

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print common_trends
# Out:
# set([u'#BrentTo400k', u'#20ReasonsWhyWeLoveHarry', u'#20picturesofharryfromyourcameraroll'])

# %%
# XXX: Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

q = '#superbowl' 

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print "Length of statuses", len(statuses)
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError, e: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print json.dumps(statuses[0], indent=1)
# Out:
# Length of statuses 99
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "RT @Hooligan_Nation: #2MoreDays! @BrunoMars and the Hooligans take over the #SuperBowl @MLStadium #GetHypedForHalftime http://t.co/8SzelNEq\u2026",
#  "in_reply_to_status_id": null,
#  "id": 429449753508593665,
#  "favorite_count": 0,
#  "source": "<a href=\"http://twitter.com/#!/download/ipad\" rel=\"nofollow\">Twitter for iPad</a>",
#  "retweeted": false,
#  "coordinates": null,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [
#    {
#     "id": 1906368956,
#     "indices": [
#      3,
#      19
#     ],
#     "id_str": "1906368956",
#     "screen_name": "Hooligan_Nation",
#     "name": "Hooligan Nation"
#    },
#    {
#     "id": 100220864,
#     "indices": [
#      33,
#      43
#     ],
#     "id_str": "100220864",
#     "screen_name": "BrunoMars",
#     "name": "Bruno Mars"
#    },
#    {
#     "id": 84434832,
#     "indices": [
#      87,
#      97
#     ],
#     "id_str": "84434832",
#     "screen_name": "MLStadium",
#     "name": "MetLife Stadium"
#    }
#   ],
#   "hashtags": [
#    {
#     "indices": [
#      21,
#      31
#     ],
#     "text": "2MoreDays"
#    },
#    {
#     "indices": [
#      76,
#      86
#     ],
#     "text": "SuperBowl"
#    },
#    {
#     "indices": [
#      98,
#      118
#     ],
#     "text": "GetHypedForHalftime"
#    }
#   ],
#   "urls": [],
#   "media": [
#    {
#     "expanded_url": "http://twitter.com/Hooligan_Nation/status/429434356457676801/photo/1",
#     "display_url": "pic.twitter.com/8SzelNEq25",
#     "url": "http://t.co/8SzelNEq25",
#     "media_url_https": "https://pbs.twimg.com/media/BfWoRZZCEAA9yLu.jpg",
#     "id_str": "429434356310872064",
#     "sizes": {
#      "large": {
#       "h": 482,
#       "resize": "fit",
#       "w": 554
#      },
#      "small": {
#       "h": 295,
#       "resize": "fit",
#       "w": 339
#      },
#      "medium": {
#       "h": 482,
#       "resize": "fit",
#       "w": 554
#      },
#      "thumb": {
#       "h": 150,
#       "resize": "crop",
#       "w": 150
#      }
#     },
#     "indices": [
#      139,
#      140
#     ],
#     "type": "photo",
#     "id": 429434356310872064,
#     "media_url": "http://pbs.twimg.com/media/BfWoRZZCEAA9yLu.jpg"
#    }
#   ]
#  },
#  "in_reply_to_screen_name": null,
#  "in_reply_to_user_id": null,
#  "retweet_count": 16,
#  "id_str": "429449753508593665",
#  "favorited": false,
#  "retweeted_status": {
#   "contributors": null,
#   "truncated": false,
#   "text": "#2MoreDays! @BrunoMars and the Hooligans take over the #SuperBowl @MLStadium #GetHypedForHalftime http://t.co/8SzelNEq25",
#   "in_reply_to_status_id": null,
#   "id": 429434356457676801,
#   "favorite_count": 14,
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 100220864,
#      "indices": [
#       12,
#       22
#      ],
#      "id_str": "100220864",
#      "screen_name": "BrunoMars",
#      "name": "Bruno Mars"
#     },
#     {
#      "id": 84434832,
#      "indices": [
#       66,
#       76
#      ],
#      "id_str": "84434832",
#      "screen_name": "MLStadium",
#      "name": "MetLife Stadium"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       0,
#       10
#      ],
#      "text": "2MoreDays"
#     },
#     {
#      "indices": [
#       55,
#       65
#      ],
#      "text": "SuperBowl"
#     },
#     {
#      "indices": [
#       77,
#       97
#      ],
#      "text": "GetHypedForHalftime"
#     }
#    ],
#    "urls": [],
#    "media": [
#     {
#      "expanded_url": "http://twitter.com/Hooligan_Nation/status/429434356457676801/photo/1",
#      "display_url": "pic.twitter.com/8SzelNEq25",
#      "url": "http://t.co/8SzelNEq25",
#      "media_url_https": "https://pbs.twimg.com/media/BfWoRZZCEAA9yLu.jpg",
#      "id_str": "429434356310872064",
#      "sizes": {
#       "large": {
#        "h": 482,
#        "resize": "fit",
#        "w": 554
#       },
#       "small": {
#        "h": 295,
#        "resize": "fit",
#        "w": 339
#       },
#       "medium": {
#        "h": 482,
#        "resize": "fit",
#        "w": 554
#       },
#       "thumb": {
#        "h": 150,
#        "resize": "crop",
#        "w": 150
#       }
#      },
#      "indices": [
#       98,
#       120
#      ],
#      "type": "photo",
#      "id": 429434356310872064,
#      "media_url": "http://pbs.twimg.com/media/BfWoRZZCEAA9yLu.jpg"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 16,
#   "id_str": "429434356457676801",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 1906368956,
#    "profile_background_image_url_https": "https://si0.twimg.com/profile_background_images/378800000082618144/8ba04b69378c367ea6f5f85d1577181c.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000830933104/baa5729b5972b5edcf2f51d976185f6b_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/VDWdLFccyZ",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://instagram.com/hn_nation",
#        "display_url": "instagram.com/hn_nation"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 3204,
#    "profile_sidebar_border_color": "FFFFFF",
#    "id_str": "1906368956",
#    "profile_background_color": "C0DEED",
#    "listed_count": 37,
#    "is_translation_enabled": false,
#    "utc_offset": -28800,
#    "statuses_count": 9126,
#    "description": "Welcome to Hooligan Nation; the 1st & ONLY page dedicated to @BrunoMars & ALL The Hooligans. You love them, we love you! Founded 9/25/2013 we ALWAYS #FollowBack",
#    "friends_count": 3379,
#    "location": "All Around The World",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/378800000830933104/baa5729b5972b5edcf2f51d976185f6b_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/1906368956/1382490338",
#    "profile_background_image_url": "http://a0.twimg.com/profile_background_images/378800000082618144/8ba04b69378c367ea6f5f85d1577181c.png",
#    "screen_name": "Hooligan_Nation",
#    "lang": "en",
#    "profile_background_tile": true,
#    "favourites_count": 2089,
#    "name": "Hooligan Nation",
#    "notifications": false,
#    "url": "http://t.co/VDWdLFccyZ",
#    "created_at": "Thu Sep 26 03:03:31 +0000 2013",
#    "contributors_enabled": false,
#    "time_zone": "Pacific Time (US & Canada)",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Sat Feb 01 02:01:43 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  "user": {
#   "follow_request_sent": false,
#   "profile_use_background_image": true,
#   "default_profile_image": false,
#   "id": 559985740,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "verified": false,
#   "profile_text_color": "333333",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000716811752/63d0b1af3ea6cbed55a72d99fa1cfb2c_normal.jpeg",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "followers_count": 83,
#   "profile_sidebar_border_color": "C0DEED",
#   "id_str": "559985740",
#   "profile_background_color": "C0DEED",
#   "listed_count": 0,
#   "is_translation_enabled": false,
#   "utc_offset": null,
#   "statuses_count": 10534,
#   "description": "",
#   "friends_count": 167,
#   "location": "Colton, CA",
#   "profile_link_color": "0084B4",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/378800000716811752/63d0b1af3ea6cbed55a72d99fa1cfb2c_normal.jpeg",
#   "following": false,
#   "geo_enabled": false,
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "screen_name": "kyna_torres",
#   "lang": "en",
#   "profile_background_tile": false,
#   "favourites_count": 5302,
#   "name": "Kyna S  Torres",
#   "notifications": false,
#   "url": null,
#   "created_at": "Sun Apr 22 01:40:01 +0000 2012",
#   "contributors_enabled": false,
#   "time_zone": null,
#   "protected": false,
#   "default_profile": true,
#   "is_translator": false
#  },
#  "geo": null,
#  "in_reply_to_user_id_str": null,
#  "possibly_sensitive": false,
#  "lang": "en",
#  "created_at": "Sat Feb 01 03:02:54 +0000 2014",
#  "in_reply_to_status_id_str": null,
#  "place": null,
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  }
# }

# %%
import json 

type(statuses[0])
# Out:
# dict

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print json.dumps(status_texts[0:5], indent=1)
print json.dumps(screen_names[0:5], indent=1) 
print json.dumps(hashtags[0:5], indent=1)
print json.dumps(words[0:5], indent=1)
# Out:
# [
#  "RT @Hooligan_Nation: #2MoreDays! @BrunoMars and the Hooligans take over the #SuperBowl @MLStadium #GetHypedForHalftime http://t.co/8SzelNEq\u2026",
#  "RT @MarcAnthony: La banda suena super en ensayo para fiesta de Super Bowl esta noche en NY! #SuperBowl http://t.co/7Ospl9ATup",
#  "RT @DarnaaMusic: The #SuperBowl tickets I am giving away are in the100s section.  The I died and went to heaven section. @angelayee @breakf\u2026",
#  "RT @Budweiser: If you can't wait for the #SuperBowl, watch our tribute to an American hero right here http://t.co/rh7hMg0cyN #Salute http:/\u2026",
#  "#superbowl music tour stop two:\n#WalkTheMoon #BudLightHotel http://t.co/Rx8e4z7Acl"
# ]
# [
#  "Hooligan_Nation",
#  "BrunoMars",
#  "MLStadium",
#  "MarcAnthony",
#  "DarnaaMusic"
# ]
# [
#  "2MoreDays",
#  "SuperBowl",
#  "GetHypedForHalftime",
#  "SuperBowl",
#  "SuperBowl"
# ]
# [
#  "RT",
#  "@Hooligan_Nation:",
#  "#2MoreDays!",
#  "@BrunoMars",
#  "and"
# ]

# %%
status_texts
# Out:
# [u'RT @Hooligan_Nation: #2MoreDays! @BrunoMars and the Hooligans take over the #SuperBowl @MLStadium #GetHypedForHalftime http://t.co/8SzelNEq\u2026',
#  u'RT @MarcAnthony: La banda suena super en ensayo para fiesta de Super Bowl esta noche en NY! #SuperBowl http://t.co/7Ospl9ATup',
#  u'RT @DarnaaMusic: The #SuperBowl tickets I am giving away are in the100s section.  The I died and went to heaven section. @angelayee @breakf\u2026',
#  u"I'm ready for Sunday.. Are? #SuperBowl #wings #lilsmokies #rotel #Natty http://t.co/IYU2XeqHkL",
#  u'only in New York \U0001f60f\U0001f44c\U0001f3c8 \U0001f5fd#SuperBowl #TimesSquare #GreatTimeWithGreatPeople http://t.co/mNX5ghEMlA',
#  u'Al final...\nQue tema van a tocar los Red Hot en el #SuperBowl?',
#  u'RT @KLDDesigns: #GodBless our troops \u201c@Budweiser: #SuperBowl tribute to an American hero http://t.co/o3v67VGM5W #Salute http://t.co/asyg8Xr\u2026',
#  u"Seriously the funniest thing I've seen in my life #superbowl lmfao\U0001f602\U0001f602\U0001f602 http://t.co/sPyGX3ouG2"]

# %%
hashtags
# Out:
# [u'2MoreDays',
#  u'SuperBowl',
#  u'GetHypedForHalftime',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'Salute',
#  u'superbowl',
#  u'WalkTheMoon',
#  u'BudLightHotel',
#  u'Fun',
#  u'Fact',
#  u'Friday',
#  u'Football',
#  u'SuperBowl',
#  u'math',
#  u'SuperBowl',
#  u'MTFBWY',
#  u'HuttHuttHike',
#  u'canubelievethis',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'Salute',
#  u'Superbowl',
#  u'Seahawks',
#  u'Superbowl',
#  u'Ortega',
#  u'NFL',
#  u'StonerBowl',
#  u'SuperBowl',
#  u'TommyChong',
#  u'VinceLombardiTrophy',
#  u'SuperBowl',
#  u'Salute',
#  u'SegundaVuelta',
#  u'SuperBowl',
#  u'marcas',
#  u'stepandrepeat',
#  u'ESPNTHEPARTY',
#  u'SuperBowl',
#  u'party',
#  u'Superbowl',
#  u'ImTheBest',
#  u'Seahawks',
#  u'SuperBowl',
#  u'21YearsAgoToday',
#  u'Superbowl',
#  u'NFLHouse',
#  u'NYC',
#  u'Beardown',
#  u'Superbowl',
#  u'Superbowl',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'givemeallthecarbsandcheese',
#  u'SuperBowl',
#  u'bluefriday',
#  u'gohawks',
#  u'superbowl',
#  u'ChryslerSuperBowl',
#  u'KateUpton',
#  u'SuperBowl',
#  u'WillemDafoe',
#  u'NoFrankYou',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'GameDay',
#  u'Recipe',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'NFL',
#  u'SuperBowl',
#  u'vk',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'Salute',
#  u'SuperBowl',
#  u'NFL',
#  u'dontask',
#  u'iwonttell',
#  u'SuperBowl',
#  u'Seahawks',
#  u'SuperBowl',
#  u'orange',
#  u'superbowl',
#  u'superbowloutfit',
#  u'SuperBowl',
#  u'PartyPlatters',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'GoBroncos',
#  u'SuperBowl',
#  u'Champions',
#  u'Smackdown',
#  u'SuperBowl',
#  u'RAW',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'Doberhuahua',
#  u'newyorkcity',
#  u'superbowl',
#  u'SUPERBOWL',
#  u'RETWEET',
#  u'TeamFollowBack',
#  u'Follow2BeFollowed',
#  u'SuperBowl',
#  u'rickdyer',
#  u'superbowl',
#  u'scam',
#  u'internetfraud',
#  u'SuperBowl',
#  u'NFL',
#  u'football',
#  u'sports',
#  u'YOLO',
#  u'SuperBowl',
#  u'superbowl',
#  u'HeeJungChern',
#  u'SuperBowl',
#  u'Superbowl',
#  u'AirForce',
#  u'biggame',
#  u'SuperBowl',
#  u'NewJersey',
#  u'NewYork',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'Salute',
#  u'SuperBowl',
#  u'superbowl',
#  u'PAMASmackdown',
#  u'SuperBowl',
#  u'HeraldSquare',
#  u'GetYourWings',
#  u'SuperBowl',
#  u'Salute',
#  u'SuperBowl',
#  u'NFL',
#  u'JeffreyLurie',
#  u'NativeAmerican',
#  u'PhiladelphiaEagles',
#  u'SuperBowl',
#  u'FF',
#  u'SuperBowl',
#  u'RT',
#  u'FollowFriday',
#  u'spreadthelove',
#  u'Comedy',
#  u'RetroGaming',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'TypicalNewYork',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'MTFBWY',
#  u'HuttHuttHike',
#  u'SuperBowl',
#  u'SB48',
#  u'superbowl',
#  u'nyc',
#  u'SuperBowl',
#  u'SportsAtHomeSuperBowlPick',
#  u'mayhem',
#  u'sports',
#  u'superbowl',
#  u'hollywood',
#  u'party',
#  u'partyinhollywood',
#  u'sportsbar',
#  u'broncos',
#  u'superbowl',
#  u'gameday',
#  u'Football',
#  u'food',
#  u'SuperBowl',
#  u'abetterweb',
#  u'SuperBowl',
#  u'foreverandever',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'News',
#  u'superbowl',
#  u'trafficking',
#  u'canonclast',
#  u'SuperBowl',
#  u'vegas',
#  u'henderson',
#  u'SuperBowl',
#  u'Salute',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'MTFBWY',
#  u'HuttHuttHike',
#  u'healthy',
#  u'SuperBowl',
#  u'recipes',
#  u'SuperBowl',
#  u'NFL',
#  u'Mayweather',
#  u'SuperBowl',
#  u'SuperBowl',
#  u'wings',
#  u'lilsmokies',
#  u'rotel',
#  u'Natty',
#  u'SuperBowl',
#  u'TimesSquare',
#  u'GreatTimeWithGreatPeople',
#  u'SuperBowl',
#  u'GodBless',
#  u'SuperBowl',
#  u'Salute',
#  u'superbowl']

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print c.most_common()[:10] # top 10
    print
# Out:
# [(u'#SuperBowl', 120), (u'the', 90), (u'RT', 84), (u'to', 45), (u'in', 34), (u'and', 33), (u'a', 30), (u'for', 29), (u'#superbowl', 26), (u'of', 26)]
#
# [(u'RollingStone', 8), (u'SodaStream', 5), (u'foxsports910', 5), (u'Seahawks', 5), (u'Broncos', 4), (u'marcogreenberg', 4), (u'kentsomers', 3), (u'OtisWilson_55', 3), (u'NJTRANSIT', 3), (u'mikejurecki', 3)]
#
# [(u'SuperBowl', 143), (u'superbowl', 30), (u'Superbowl', 23), (u'NFL', 14), (u'Broncos', 8), (u'BDS', 5), (u'seahawks', 4), (u'GoHawks', 4), (u'SUPERBOWL', 4), (u'Israel', 4)]

# %%
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print pt
# Out:
# +------------+-------+
# | Word       | Count |
# +------------+-------+
# | #SuperBowl |   120 |
# | the        |    90 |
# | RT         |    84 |
# | to         |    45 |
# | in         |    34 |
# | and        |    33 |
# | a          |    30 |
# | for        |    29 |
# | #superbowl |    26 |
# | of         |    26 |
# +------------+-------+
# +----------------+-------+
# | Screen Name    | Count |
# +----------------+-------+
# | RollingStone   |     8 |
# | SodaStream     |     5 |
# | foxsports910   |     5 |
# | Seahawks       |     5 |
# | Broncos        |     4 |
# | marcogreenberg |     4 |
# | kentsomers     |     3 |
# | OtisWilson_55  |     3 |
# | NJTRANSIT      |     3 |
# | mikejurecki    |     3 |
# +----------------+-------+
# +-----------+-------+
# | Hashtag   | Count |
# +-----------+-------+
# | SuperBowl |   143 |
# | superbowl |    30 |
# | Superbowl |    23 |
# | NFL       |    14 |
# | Broncos   |     8 |
# | BDS       |     5 |
# | seahawks  |     4 |
# | GoHawks   |     4 |
# | SUPERBOWL |     4 |
# | Israel    |     4 |
# +-----------+-------+

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print lexical_diversity(words)
print lexical_diversity(screen_names)
print lexical_diversity(hashtags)
print average_words(status_texts)
# Out:
# 0.509958899779
# 0.718309859155
# 0.410377358491
# 15.815

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if status.has_key('retweeted_status')
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print pt
# Out:
# +-------+-------------+----------------------------------------------------+
# | Count | Screen Name | Text                                               |
# +-------+-------------+----------------------------------------------------+
# | 4724  | tree_bro    | RT @tree_bro: Why Can't I Find Out Anything About  |
# |       |             | This Superb Owl #superbowl                         |
# | 4724  | tree_bro    | RT @tree_bro: Why Can't I Find Out Anything About  |
# |       |             | This Superb Owl #superbowl                         |
# | 470   | DavidSpade  | RT @DavidSpade: This guy better be at the          |
# |       |             | #Superbowl or I'm not watching                     |
# |       |             | http://t.co/hgbKnHy6kl                             |
# | 360   | ReillyRick  | RT @ReillyRick: Asked Russell Wilson if he can see |
# |       |             | himself playing as long as Peyton Manning. "Oh my  |
# |       |             | goal is to play 20 years all in Seattl…            |
# | 148   | Strideline  | RT @Strideline: Just got a fresh shipment of       |
# |       |             | "Hawks" socks. RT this tweet to win a pair.        |
# |       |             | #GoHawks #SuperBowl http://t.co/OVm8mMoZeY         |
# +-------+-------------+----------------------------------------------------+

# %%
# Get the original tweet id for a tweet from its retweeted_status node 
# and insert it here in place of the sample value that is provided
# from the text of the book

_retweets = twitter_api.statuses.retweets(id=317127304981667841)
print [r['user']['screen_name'] for r in _retweets]
# Out:
# [u'jyeee', u'Ceejaynatics', u'Majendalove', u'shameeennnn', u'EmilyearoRuiz', u'Oliviyaaay', u'ShikaynaAryan', u'RafaellaaaMae', u'LoveKyana18', u'iiaamcamille', u'figueroangelene', u'Aileenylalalove', u'mikaachuu', u'kidamgos', u'ShaaaronOng', u'asdfghjbl']

# %%
import pyplot as plt

word_counts = sorted(Counter(words).values(), reverse=True)

plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-20-b3e57b183152> in <module>()
# ----> 1 import pyplot as plt
#       2
#       3 word_counts = sorted(Counter(words).values(), reverse=True)
#       4
#       5 plt.loglog(word_counts)
#
# ImportError: No module named pyplot

# %%
for label, data in (('Words', words), 
                    ('Screen Names', screen_names), 
                    ('Hashtags', hashtags)):

    # Build a frequency map for each set of data
    # and plot the values
    c = Counter(data)
    plt.hist(c.values())
    
    # Add a title and y-label ...
    plt.title(label)
    plt.ylabel("Number of items in bin")
    plt.xlabel("Bins (number of times an item appeared)")
    
    # ... and display as a new figure
    plt.figure()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-32220092a0d6> in <module>()
#       6     # and plot the values
#       7     c = Counter(data)
# ----> 8     plt.hist(c.values())
#       9
#      10     # Add a title and y-label ...
#
# NameError: name 'plt' is not defined

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')

print counts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-330377243321> in <module>()
#       4 counts = [count for count, _, _ in retweets]
#       5
# ----> 6 plt.hist(counts)
#       7 plt.title("Retweets")
#       8 plt.xlabel('Bins (number of times retweeted)')
#
# NameError: name 'plt' is not defined

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

# Taking the log of the *data values* themselves can 
# often provide quick and valuable insight into the
# underlying distribution as well. Try it back on
# Example 13 and see if it helps.

plt.hist(log(counts))
plt.title("Retweets")
plt.xlabel('Log[Bins (number of times retweeted)]')
plt.ylabel('Log[Number of tweets in bin]')

print log(counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-0941d50391b4> in <module>()
#       9 # Example 13 and see if it helps.
#      10
# ---> 11 plt.hist(log(counts))
#      12 plt.title("Retweets")
#      13 plt.xlabel('Log[Bins (number of times retweeted)]')
#
# NameError: name 'plt' is not defined
